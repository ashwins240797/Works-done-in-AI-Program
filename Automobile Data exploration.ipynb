# %%
import pandas as pd
import numpy as np

df = pd.read_csv("D://M_AI//Machine Learning//Data Preprocessing//mtcars.csv")
Model_Type = np.array(df['model'])
Avg_HP = np.array(df['hp'])
Disp = np.array(df['disp'])
print(df)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
# Checking for missing values
df.isna().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
# checking for outlier values
import seaborn as sns
sns.boxplot(x=df['hp'])

# %%
# to treat that outlier value
filter = df['hp'].values>275
df_outlier_rem = df[filter]
df_outlier_rem
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
north_america = pd.read_csv("D://M_AI//Machine Learning//Demo Datasets//Lesson 3//north_america_2000_2010.csv",index_col = 0)
north_america
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0

# %%
south_america = pd.read_csv("D://M_AI//Machine Learning//Demo Datasets//Lesson 3//south_america_2000_2010.csv",index_col = 0)
south_america
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009    2010
# Country
# Chile    2263  2242  2250  2235  2232  2157  2165  2128  2095  2074  2069.6

# %%
# concatenation
americas = pd.concat([north_america,south_america])
americas
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# Chile    2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0
# Chile    2074.0  2069.6
